# %% [markdown]
# <a href="https://colab.research.google.com/github/kalki81000/Assaignments/blob/main/Untitled72.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # #Question 1.1 write the Answer the follwing of these question

# %%
#1.what is the difference between dynamic and static variable in python?
In Python, the terms "dynamic" and "static" variables are not used in the same way they might be in some other languages. Instead, Python has a more flexible approach to variable types and scoping. However, the concept can still be understood in a Pythonic context:

### Static Variables

In some languages, a static variable is one that retains its value across function calls. Python doesn’t have static variables in the same sense, but you can achieve similar behavior using function attributes or class attributes.

- **Function Attributes**: You can use attributes on functions to maintain state across calls.

  ```python
  def counter():
      counter.count += 1
      return counter.count

  counter.count = 0  # Initialize the static-like variable

  print(counter())  # Output: 1
  print(counter())  # Output: 2
  ```

- **Class Attributes**: In the context of classes, class attributes can act like static variables, shared among all instances of the class.

  ```python
  class MyClass:
      static_variable = 0

      def increment(self):
          MyClass.static_variable += 1
          return MyClass.static_variable

  obj1 = MyClass()
  obj2 = MyClass()

  print(obj1.increment())  # Output: 1
  print(obj2.increment())  # Output: 2
  ```

### Dynamic Variables

Dynamic variables in Python refer to variables whose types and values can change at runtime. In Python, all variables are dynamically typed, meaning that the type of the variable is interpreted at runtime, not in advance.

- **Dynamic Typing**: In Python, variables can be reassigned to different types of values at runtime without any type declarations.

  ```python
  x = 5           # x is an integer
  x = "Hello"     # Now x is a string
  x = [1, 2, 3]   # Now x is a list
  ```

- **Dynamic Scoping**: Variables in Python have dynamic scoping with respect to their namespaces. For example, variables defined inside a function are not accessible outside of it unless returned or explicitly defined in a broader scope.

  ```python
  def my_function():
      y = 10
      return y

  print(my_function())  # Output: 10
  print(y)              # Raises NameError: name 'y' is not defined
  ```

In summary:

- **Static-like Variables**: In Python, these can be simulated using function attributes or class attributes.
- **Dynamic Variables**: Python variables are dynamically typed and can change types at runtime, reflecting Python’s flexible and dynamic nature.

# %%
#2.Explain the purpose of pop , popitem , clear(), in a dictionary with suitable example
In Python, dictionaries are versatile data structures that support various methods for managing their content. Here’s an explanation of `pop()`, `popitem()`, and `clear()`, along with examples for each:

### 1. `pop()`

**Purpose:**
The `pop()` method removes a specific key from the dictionary and returns its associated value. If the key is not found, it raises a `KeyError` unless a default value is provided.

**Syntax:**
```python
dict.pop(key, default)
```

- `key`: The key you want to remove.
- `default` (optional): A value to return if the key is not found. If not provided and the key is missing, a `KeyError` is raised.

**Example:**
```python
my_dict = {'a': 1, 'b': 2, 'c': 3}

# Remove the key 'b' and get its value
value = my_dict.pop('b')
print(value)         # Output: 2
print(my_dict)       # Output: {'a': 1, 'c': 3}

# Remove a non-existent key with default value
value = my_dict.pop('z', 'default_value')
print(value)         # Output: default_value
```

### 2. `popitem()`

**Purpose:**
The `popitem()` method removes and returns the last key-value pair added to the dictionary as a tuple. In Python 3.7 and later, dictionaries maintain insertion order, so `popitem()` will remove the last inserted item. In earlier versions of Python, the behavior is not guaranteed to be order-preserving.

**Syntax:**
```python
dict.popitem()
```

**Example:**
```python
my_dict = {'a': 1, 'b': 2, 'c': 3}

# Remove the last item (in this case, 'c': 3)
item = my_dict.popitem()
print(item)         # Output: ('c', 3)
print(my_dict)      # Output: {'a': 1, 'b': 2}

# If the dictionary is empty, popitem() will raise a KeyError
```

### 3. `clear()`

**Purpose:**
The `clear()` method removes all key-value pairs from the dictionary, effectively emptying it.

**Syntax:**
```python
dict.clear()
```

**Example:**
```python
my_dict = {'a': 1, 'b': 2, 'c': 3}

# Remove all items from the dictionary
my_dict.clear()
print(my_dict)      # Output: {}
```

### Summary

- **`pop(key, default)`**: Removes a specific key and returns its value. Allows you to handle missing keys with an optional default value.
- **`popitem()`**: Removes and returns the last key-value pair (Python 3.7+ maintains insertion order).
- **`clear()`**: Empties the dictionary, removing all key-value pairs.

These methods provide flexibility in managing and manipulating dictionaries based on your needs.

# %%
#3. what do you mean by frozen set?Explian it with suitable examples
A `frozenset` is an immutable version of a `set` in Python. Unlike regular sets, once a `frozenset` is created, you cannot modify its elements—no adding or removing items. It supports set operations like union, intersection, and difference but does not change itself. Because it is immutable, a `frozenset` can be used as a dictionary key or an element of another set.

**Examples:**

1. **Creating a frozenset:**
   ```python
   frozen_set = frozenset([1, 2, 3])
   ```

2. **Set operations:**
   ```python
   set1 = frozenset([1, 2])
   set2 = frozenset([2, 3])
   union = set1 | set2        # frozenset({1, 2, 3})
   intersection = set1 & set2 # frozenset({2})
   ```

3. **Using as a dictionary key:**
   ```python
   my_dict = {frozenset([1, 2]): "value"}
   ```

In essence, a `frozenset` provides a way to work with sets that cannot be altered after creation.

# %%
#4.Differentiate between mutable and immutable data types in python and givies example of mutable and immutable data types.
In Python, data types are classified as either mutable or immutable based on whether their values can be changed after they are created.

### Mutable Data Types
- **Definition**: Can be modified after creation.
- **Examples**:
  - **List**: `[1, 2, 3]` (You can add, remove, or change elements)
  - **Dictionary**: `{'a': 1, 'b': 2}` (You can add, remove, or change key-value pairs)
  - **Set**: `{1, 2, 3}` (You can add or remove elements)

  **Example:**
  ```python
  my_list = [1, 2, 3]
  my_list[0] = 10  # Modifies the list
  print(my_list)   # Output: [10, 2, 3]
  ```

### Immutable Data Types
- **Definition**: Cannot be modified after creation.
- **Examples**:
  - **Tuple**: `(1, 2, 3)` (You cannot change its elements)
  - **String**: `"hello"` (You cannot change individual characters)
  - **Frozenset**: `frozenset([1, 2, 3])` (You cannot add or remove elements)

  **Example:**
  ```python
  my_tuple = (1, 2, 3)
  # my_tuple[0] = 10  # Raises TypeError: 'tuple' object does not support item assignment
  ```

In summary:
- **Mutable** types can be changed after creation.
- **Immutable** types cannot be changed after creation.

# %%
#5.what is __init__?explain with an example
In Python, `__init__` is a special method used for initializing newly created objects of a class. It is known as the constructor method and is called automatically when an instance of a class is created.

### Purpose
- **Initialize Object**: `__init__` is used to set up initial values for the object's attributes.

### Syntax
```python
class ClassName:
    def __init__(self, parameters):
        # Initialize attributes
        self.attribute = parameters
```

### Example
```python
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

# Creating an instance of Person
person1 = Person("Alice", 30)

print(person1.name)  # Output: Alice
print(person1.age)   # Output: 30
```

In this example:
- `__init__` initializes the `name` and `age` attributes for each `Person` object.
- When `Person("Alice", 30)` is called, `__init__` sets `person1.name` to "Alice" and `person1.age` to 30.

# %%
#what is docstring in python ?explain with an example
In Python, a **docstring** is a special type of comment used to describe the purpose and usage of a function, class, or module. It is written within triple quotes (`"""` or `'''`) and appears immediately after the definition of a function, class, or module. Docstrings are used for documentation purposes and can be accessed programmatically using the `.__doc__` attribute.

### Purpose
- **Documentation**: Provides a convenient way to document code directly within the codebase.
- **Help Function**: Can be accessed via built-in functions like `help()` to provide information about the code.

### Syntax
```python
def function_name(parameters):
    """
    Description of the function.

    Args:
    parameters: Description of the parameters.

    Returns:
    Description of the return value.
    """
    pass
```

### Example
```python
def add(a, b):
    """
    Adds two numbers and returns the result.

    Args:
    a (int or float): The first number.
    b (int or float): The second number.

    Returns:
    int or float: The sum of the two numbers.
    """
    return a + b

print(add.__doc__)
```

**Output:**
```
Adds two numbers and returns the result.

Args:
a (int or float): The first number.
b (int or float): The second number.

Returns:
int or float: The sum of the two numbers.
```

### Accessing Docstrings
You can access the docstring of a function, class, or module using the `.__doc__` attribute or the `help()` function.

**Example using `help()`:**
```python
help(add)
```

This will display the docstring for the `add` function, providing users with a description of what the function does and its parameters.

# %%
#what are unit tests in python?
**Unit tests** in Python are automated tests designed to verify that individual components (units) of code, such as functions or methods, work correctly. They are typically written using the `unittest` framework or other testing libraries like `pytest`.

### Purpose
- **Validate Functionality**: Ensure that each unit of the code behaves as expected.
- **Catch Bugs**: Identify issues early in the development process.
- **Facilitate Refactoring**: Make it safer to change code by ensuring that tests confirm code still works as intended.

### Example with `unittest`

1. **Writing Unit Tests**

   ```python
   import unittest

   def add(a, b):
       return a + b

   class TestMathOperations(unittest.TestCase):
       def test_add(self):
           self.assertEqual(add(2, 3), 5)
           self.assertEqual(add(-1, 1), 0)

   if __name__ == "__main__":
       unittest.main()
   ```

2. **Running Unit Tests**

   - Save the code in a file, e.g., `test_math.py`.
   - Run the tests from the command line using:
     ```bash
     python -m unittest test_math.py
     ```

   This will execute the test cases and report any failures or errors.

In summary, unit tests help ensure that individual parts of your code work correctly and help maintain code quality over time.

# %%
#what is break , continue and pass in python?
In Python, `break`, `continue`, and `pass` are control flow statements used to manage the flow of loops and conditional blocks.

### `break`
- **Purpose**: Exits the nearest enclosing loop (for or while) immediately, skipping any remaining iterations.
- **Example**:
  ```python
  for i in range(5):
      if i == 3:
          break
      print(i)
  # Output: 0 1 2
  ```

### `continue`
- **Purpose**: Skips the rest of the current loop iteration and moves to the next iteration of the loop.
- **Example**:
  ```python
  for i in range(5):
      if i == 3:
          continue
      print(i)
  # Output: 0 1 2 4
  ```

### `pass`
- **Purpose**: Acts as a placeholder where code is syntactically required but no action is desired. It does nothing and allows the code to continue.
- **Example**:
  ```python
  for i in range(5):
      if i == 3:
          pass  # Placeholder for future code
      else:
          print(i)
  # Output: 0 1 2 4
  ```

**Summary:**
- `break` exits a loop.
- `continue` skips to the next iteration of a loop.
- `pass` serves as a placeholder for future code.

# %%
#what is the use of self in python ?
In Python, `self` is a reference to the current instance of a class. It is used within class methods to access instance attributes and other methods. `self` allows methods to refer to the instance that called them, enabling object-specific behavior and state management.

### Usage
- **Access Instance Attributes**: Retrieve or modify attributes specific to the instance.
- **Call Other Methods**: Invoke other methods within the same class.

### Example

```python
class Person:
    def __init__(self, name, age):
        self.name = name  # Instance attribute
        self.age = age    # Instance attribute

    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")

# Creating an instance
person1 = Person("Alice", 30)
person1.greet()  # Output: Hello, my name is Alice and I am 30 years old.
```

**Summary**: `self` is used to access instance-specific data and methods within a class.

# %%
#what are global ,protected and private attribute in python ?
In Python, attributes (variables) in a class can have different levels of visibility, which determine how and where they can be accessed. These levels are global, protected, and private.

### Global Attribute
- **Definition**: A global attribute is not specific to any class but is accessible from anywhere in the code.
- **Example**:
  ```python
  global_var = 10  # Global attribute

  class MyClass:
      def __init__(self):
          print(global_var)  # Accessing global attribute

  obj = MyClass()  # Output: 10
  ```

### Protected Attribute
- **Definition**: A protected attribute is intended for internal use within a class and its subclasses. It is indicated by a single underscore (`_`).
- **Example**:
  ```python
  class Base:
      def __init__(self):
          self._protected_var = 20  # Protected attribute

  class Derived(Base):
      def print_var(self):
          print(self._protected_var)  # Accessing protected attribute

  obj = Derived()
  obj.print_var()  # Output: 20
  ```

### Private Attribute
- **Definition**: A private attribute is intended to be inaccessible from outside the class. It is indicated by a double underscore (`__`).
- **Example**:
  ```python
  class MyClass:
      def __init__(self):
          self.__private_var = 30  # Private attribute

      def get_private_var(self):
          return self.__private_var  # Accessing private attribute within the class

  obj = MyClass()
  print(obj.get_private_var())  # Output: 30

  # Attempting to access directly
  # print(obj.__private_var)  # Raises AttributeError
  ```

**Summary**:
- **Global**: Accessible from anywhere in the code.
- **Protected**: Intended for use within the class and its subclasses (single underscore `_`).
- **Private**: Restricted to the class itself (double underscore `__`).

# %%
#what are the module and package in python ?
In Python, **modules** and **packages** are ways to organize and manage code.

### Module
- **Definition**: A module is a single file containing Python code. It can include functions, classes, variables, and runnable code.
- **Purpose**: Used to group related code into a file to be reused in other scripts.
- **Example**:
  ```python
  # math_utils.py (a module)
  def add(a, b):
      return a + b
  ```

  ```python
  # main.py
  import math_utils

  result = math_utils.add(5, 3)
  print(result)  # Output: 8
  ```

### Package
- **Definition**: A package is a directory containing multiple modules and an `__init__.py` file (can be empty). It allows for organizing modules into a directory hierarchy.
- **Purpose**: Used to structure related modules into a directory to manage larger codebases.
- **Example**:
  ```
  my_package/
  ├── __init__.py
  ├── module1.py
  └── module2.py
  ```

  ```python
  # my_package/module1.py
  def greet(name):
      return f"Hello, {name}!"
  ```

  ```python
  # main.py
  from my_package import module1

  message = module1.greet("Alice")
  print(message)  # Output: Hello, Alice!
  ```

**Summary**:
- **Module**: A single file containing Python code.
- **Package**: A directory with multiple modules and an `__init__.py` file.

# %%
#what are list and tuple ? what is the key differnce between the two ?
**List** and **Tuple** are both data structures in Python used to store collections of items. Here’s a brief overview and their key differences:

### List
- **Definition**: An ordered collection of items that can be changed.
- **Syntax**: Created using square brackets `[ ]`.
- **Mutability**: Mutable (can be modified after creation).
- **Example**:
  ```python
  my_list = [1, 2, 3]
  my_list.append(4)  # Modifies the list
  ```

### Tuple
- **Definition**: An ordered collection of items that cannot be changed.
- **Syntax**: Created using parentheses `( )`.
- **Mutability**: Immutable (cannot be modified after creation).
- **Example**:
  ```python
  my_tuple = (1, 2, 3)
  # my_tuple[0] = 10  # Raises TypeError
  ```

### Key Differences
- **Mutability**: Lists are mutable (can be changed), while tuples are immutable (cannot be changed).
- **Syntax**: Lists use square brackets `[ ]`, while tuples use parentheses `( )`.
- **Use Case**: Lists are used when you need a collection that may change, whereas tuples are used for fixed collections of items that should not be modified.

**Summary**:
- **List**: Mutable, uses `[ ]`.
- **Tuple**: Immutable, uses `( )`.

# %%
#whta is an interpreted language & dynamically typed language ? write 5 difference between them.
### Interpreted Language

**Definition**: An interpreted language is executed line-by-line by an interpreter at runtime, without the need for a separate compilation step.

**Characteristics**:
- **Execution**: The code is read and executed directly by the interpreter.
- **Error Detection**: Errors are detected during runtime, not before execution.
- **Performance**: Typically slower than compiled languages due to real-time interpretation.
- **Development**: Often allows for interactive testing and debugging.
- **Examples**: Python, Ruby, JavaScript.

### Dynamically Typed Language

**Definition**: A dynamically typed language determines the type of a variable at runtime rather than at compile-time.

**Characteristics**:
- **Type Binding**: Variable types are checked and bound during execution.
- **Flexibility**: Variables can change types during runtime.
- **Error Detection**: Type-related errors are detected during runtime.
- **Code Simplicity**: Often requires less boilerplate code for type declarations.
- **Examples**: Python, JavaScript, PHP.

### Key Differences

1. **Execution vs. Typing**:
   - **Interpreted**: Refers to how code is executed (line-by-line).
   - **Dynamically Typed**: Refers to when and how types are determined (at runtime).

2. **Performance**:
   - **Interpreted**: Generally slower due to runtime interpretation.
   - **Dynamically Typed**: Type-related performance impacts depend on the language implementation.

3. **Error Detection**:
   - **Interpreted**: Errors are caught at runtime as the code is executed.
   - **Dynamically Typed**: Type errors are also caught at runtime, but not due to interpretation.

4. **Development Cycle**:
   - **Interpreted**: Often facilitates quick testing and iteration.
   - **Dynamically Typed**: Provides flexibility in coding, but type-related issues may surface later.

5. **Examples**:
   - **Interpreted**: Python (can be both interpreted and dynamically typed), JavaScript.
   - **Dynamically Typed**: Python, JavaScript (can also be interpreted).

**Summary**:
- **Interpreted Language**: Executes code line-by-line.
- **Dynamically Typed Language**: Determines variable types at runtime.

# %%
#what are dict and list comprehensions?
**Dict Comprehension** and **List Comprehension** are concise methods in Python for creating dictionaries and lists using a single line of code.

### List Comprehension
- **Definition**: A compact way to create a list based on an existing iterable or range, applying an optional condition.
- **Syntax**: `[expression for item in iterable if condition]`
- **Example**:
  ```python
  squares = [x**2 for x in range(10)]
  # Output: [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
  ```

### Dict Comprehension
- **Definition**: A concise way to create a dictionary where keys and values are generated from an iterable or range, with an optional condition.
- **Syntax**: `{key_expression: value_expression for item in iterable if condition}`
- **Example**:
  ```python
  square_dict = {x: x**2 for x in range(10)}
  # Output: {0: 0, 1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81}
  ```

**Summary**:
- **List Comprehension**: Creates lists efficiently with a single line.
- **Dict Comprehension**: Creates dictionaries efficiently with a single line.

# %%
#what are decorators in python ? explai it with an example write its use case ?
**Decorators** in Python are a design pattern used to modify or enhance the behavior of functions or methods without changing their code. They are essentially functions that take another function as input and return a new function with added functionality.

### How Decorators Work
- **Definition**: A decorator is a function that wraps another function to extend its behavior.
- **Syntax**: Defined using the `@decorator_name` syntax above a function.

### Example

```python
def decorator_function(original_function):
    def wrapper_function():
        print("Wrapper executed before the original function.")
        original_function()
        print("Wrapper executed after the original function.")
    return wrapper_function

@decorator_function
def say_hello():
    print("Hello!")

say_hello()
```

**Output:**
```
Wrapper executed before the original function.
Hello!
Wrapper executed after the original function.
```

### Use Case
**Logging**: Decorators can be used to add logging functionality to functions, helping in debugging and monitoring.

**Example with Logging Decorator:**

```python
def log_function_call(func):
    def wrapper(*args, **kwargs):
        print(f"Calling function: {func.__name__}")
        result = func(*args, **kwargs)
        print(f"Function {func.__name__} returned {result}")
        return result
    return wrapper

@log_function_call
def add(a, b):
    return a + b

add(3, 4)
```

**Output:**
```
Calling function: add
Function add returned 7
```

**Summary:**
- **Decorators**: Functions that enhance or modify other functions.
- **Use Case**: Useful for logging, access control, memoization, and more.

# %%
#how is memory maneged in python ?
In Python, memory management involves several key components to efficiently allocate and deallocate memory:

### Key Components

1. **Automatic Memory Management**:
   - Python automatically handles memory allocation and deallocation using a garbage collector. Developers do not need to manually manage memory.

2. **Reference Counting**:
   - Each object in Python maintains a reference count that tracks how many references point to it. When the reference count drops to zero, the memory for that object is freed.

3. **Garbage Collection**:
   - Python includes a garbage collector to handle cyclic references (where objects reference each other in a loop). The garbage collector identifies and cleans up these cycles to reclaim memory.

4. **Memory Pools**:
   - Python uses memory pools for small objects to reduce fragmentation and improve allocation efficiency. For example, the `pymalloc` allocator manages memory for small objects.

5. **Dynamic Typing**:
   - Python's dynamic typing system can cause additional memory overhead as types and object attributes are managed at runtime.

**Summary**:
- Python uses **reference counting** and **garbage collection** to manage memory.
- **Memory pools** help manage small object allocations.
- **Automatic management** simplifies memory handling for developers.

# %%
#what is lambda in python? why is it used?
A **lambda** in Python is a way to create small, anonymous functions on the fly. Lambda functions are used for short, throwaway functions that are often used as arguments to higher-order functions like `map()`, `filter()`, and `sorted()`.

### Syntax
```python
lambda arguments: expression
```

### Example
```python
# Lambda function to add two numbers
add = lambda x, y: x + y
print(add(5, 3))  # Output: 8
```

### Use Cases
- **Concise Function Definitions**: Useful for simple functions where defining a full `def` block is unnecessary.
- **Higher-Order Functions**: Often used with functions like `map()`, `filter()`, and `sorted()` for inline operations.

**Example with `map()`:**
```python
numbers = [1, 2, 3, 4]
squared = list(map(lambda x: x**2, numbers))
print(squared)  # Output: [1, 4, 9, 16]
```

**Summary**:
- **Lambda**: Creates small, anonymous functions.
- **Used**: For inline, simple functions and as arguments to other functions.

# %%
#explain split() and join() function in python ?
### `split()` Method

- **Purpose**: Splits a string into a list of substrings based on a specified delimiter.
- **Syntax**: `string.split(separator, maxsplit)`
  - `separator`: The delimiter string (default is any whitespace).
  - `maxsplit`: Maximum number of splits (default is -1, meaning "all occurrences").
- **Example**:
  ```python
  text = "apple,banana,cherry"
  fruits = text.split(",")
  print(fruits)  # Output: ['apple', 'banana', 'cherry']
  ```

### `join()` Method

- **Purpose**: Joins elements of a list (or other iterable) into a single string with a specified separator.
- **Syntax**: `separator.join(iterable)`
  - `separator`: The string used to join elements (e.g., `", "`).
  - `iterable`: The collection of strings to join.
- **Example**:
  ```python
  fruits = ['apple', 'banana', 'cherry']
  text = ", ".join(fruits)
  print(text)  # Output: "apple, banana, cherry"
  ```

**Summary**:
- **`split()`**: Breaks a string into a list of substrings.
- **`join()`**: Combines a list of strings into a single string.

# %%
#what are iterators , iterables & generatoresin python?
### Iterators
- **Definition**: Objects that implement the `__iter__()` and `__next__()` methods, allowing iteration over a sequence of values.
- **Usage**: Used to traverse through all the elements in a collection one at a time.
- **Example**:
  ```python
  numbers = [1, 2, 3]
  it = iter(numbers)  # Create an iterator
  print(next(it))  # Output: 1
  print(next(it))  # Output: 2
  ```

### Iterables
- **Definition**: Objects that implement the `__iter__()` method and can be used to obtain an iterator.
- **Usage**: Anything that you can loop over with a `for` loop.
- **Example**:
  ```python
  numbers = [1, 2, 3]  # List is an iterable
  for number in numbers:
      print(number)
  # Output: 1 2 3
  ```

### Generators
- **Definition**: Special types of iterators created using functions with `yield` statements, allowing lazy evaluation of values.
- **Usage**: Used to generate items one at a time and are memory-efficient for large sequences.
- **Example**:
  ```python
  def count_up_to(max):
      count = 1
      while count <= max:
          yield count
          count += 1

  counter = count_up_to(3)
  print(next(counter))  # Output: 1
  print(next(counter))  # Output: 2
  ```

**Summary**:
- **Iterators**: Objects that implement `__iter__()` and `__next__()` for sequential access.
- **Iterables**: Objects that provide an iterator through `__iter__()`.
- **Generators**: Special iterables created with `yield`, producing items lazily.

# %%
#what is the difference between xrange and range in python ?
In Python 2, `xrange` and `range` are used for generating sequences of numbers, but they differ in their implementation and behavior.

### `range`
- **Definition**: Creates a list of numbers.
- **Behavior**: Returns a list containing all numbers in the specified range.
- **Memory**: Uses more memory as it generates and stores the entire list of numbers.
- **Example**:
  ```python
  range_list = range(5)  # [0, 1, 2, 3, 4]
  ```

### `xrange`
- **Definition**: Generates numbers on-demand (lazy evaluation).
- **Behavior**: Returns an `xrange` object that produces numbers one at a time as needed.
- **Memory**: More memory-efficient, especially for large ranges.
- **Example**:
  ```python
  xrange_gen = xrange(5)  # Generates numbers 0 through 4 on demand
  ```

### Key Differences
- **Memory Usage**: `range` creates a full list in memory, while `xrange` generates numbers on-the-fly.
- **Python Version**: `xrange` is specific to Python 2; `range` in Python 3 behaves like `xrange` from Python 2.

**Summary**:
- **Python 2**: Use `xrange` for memory efficiency with large ranges. `range` generates a list.
- **Python 3**: `range` is implemented like `xrange` (lazy evaluation). `xrange` is not available.

# %%
#pillers of oops
The pillars of Object-Oriented Programming (OOP) are fundamental concepts that underpin the paradigm, enabling structured and reusable code. Here are the four main pillars:

### 1. **Encapsulation**
- **Definition**: Bundles data and methods that operate on the data within a single unit (class), and restricts access to some of the object's components.
- **Purpose**: Protects the internal state of an object and ensures that interactions with the object occur through well-defined interfaces.
- **Example**:
  ```python
  class Car:
      def __init__(self, make, model):
          self._make = make  # Protected attribute
          self._model = model

      def get_description(self):
          return f"{self._make} {self._model}"
  ```

### 2. **Abstraction**
- **Definition**: Hides complex implementation details and shows only the essential features of an object.
- **Purpose**: Simplifies interactions by focusing on high-level functionality while hiding internal workings.
- **Example**:
  ```python
  from abc import ABC, abstractmethod

  class Animal(ABC):
      @abstractmethod
      def make_sound(self):
          pass

  class Dog(Animal):
      def make_sound(self):
          return "Woof!"
  ```

### 3. **Inheritance**
- **Definition**: Allows a class (subclass) to inherit attributes and methods from another class (superclass).
- **Purpose**: Promotes code reuse and establishes a hierarchical relationship between classes.
- **Example**:
  ```python
  class Animal:
      def speak(self):
          return "Animal sound"

  class Dog(Animal):
      def bark(self):
          return "Woof!"
  ```

### 4. **Polymorphism**
- **Definition**: Enables different classes to be treated as instances of the same class through a common interface, often by overriding methods.
- **Purpose**: Allows for flexibility and integration of different classes through a unified interface.
- **Example**:
  ```python
  class Bird:
      def speak(self):
          return "Chirp"

  class Dog:
      def speak(self):
          return "Woof"

  def make_animal_speak(animal):
      print(animal.speak())

  make_animal_speak(Bird())  # Output: Chirp
  make_animal_speak(Dog())   # Output: Woof
  ```

**Summary**:
- **Encapsulation**: Bundling data and methods; restricting access.
- **Abstraction**: Hiding complex details; exposing essential features.
- **Inheritance**: Reusing and extending code through hierarchical relationships.
- **Polymorphism**: Using a common interface to handle different types.

# %%
#how will you check if a class is a child of another class?
To check if a class is a child (or subclass) of another class in Python, you can use the built-in `issubclass()` function.

### Syntax
```python
issubclass(subclass, superclass)
```

- **`subclass`**: The class you want to check.
- **`superclass`**: The parent class you want to check against.

### Example
```python
class Animal:
    pass

class Dog(Animal):
    pass

print(issubclass(Dog, Animal))  # Output: True
print(issubclass(Animal, Dog))  # Output: False
```

**Summary**:
- **Use `issubclass()`**: To determine if one class is a subclass of another.

# %%
#how does inheritence work in python ? Explain all types of iheritence with an example
### Types of Inheritance in Python

1. **Single Inheritance**
   - **Definition**: A subclass inherits from one superclass.
   - **Example**:
     ```python
     class Animal:
         pass
     class Dog(Animal):
         pass
     ```

2. **Multiple Inheritance**
   - **Definition**: A subclass inherits from more than one superclass.
   - **Example**:
     ```python
     class Mother:
         pass
     class Father:
         pass
     class Child(Mother, Father):
         pass
     ```

3. **Multilevel Inheritance**
   - **Definition**: A chain of inheritance (class inherits from another subclass).
   - **Example**:
     ```python
     class Grandparent:
         pass
     class Parent(Grandparent):
         pass
     class Child(Parent):
         pass
     ```

4. **Hierarchical Inheritance**
   - **Definition**: Multiple subclasses inherit from a single superclass.
   - **Example**:
     ```python
     class Animal:
         pass
     class Dog(Animal):
         pass
     class Cat(Animal):
         pass
     ```

5. **Hybrid Inheritance**
   - **Definition**: A mix of multiple inheritance types.
   - **Example**:
     ```python
     class A:
         pass
     class B(A):
         pass
     class C(A):
         pass
     class D(B, C):
         pass
     ```

**Summary**:
- **Single**: One superclass.
- **Multiple**: Multiple superclasses.
- **Multilevel**: Inheritance chain.
- **Hierarchical**: One superclass, multiple subclasses.
- **Hybrid**: Combination of inheritance types.

# %%
#whta is encapsulation ? Explain it with an eample ?**Encapsulation** in Python is the practice of bundling data (attributes) and methods (functions) that operate on the data into a single unit or class. It also involves restricting direct access to some of the object's components, which helps protect the internal state and implementation details from outside interference.

### Key Points
- **Data Hiding**: Restricts access to certain attributes or methods using visibility modifiers (e.g., private or protected).
- **Access Methods**: Provides public methods to interact with the private data, maintaining control over how the data is accessed and modified.

### Example

```python
class Account:
    def __init__(self, balance):
        self.__balance = balance  # Private attribute

    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount

    def withdraw(self, amount):
        if 0 < amount <= self.__balance:
            self.__balance -= amount

    def get_balance(self):
        return self.__balance

# Usage
acc = Account(100)
acc.deposit(50)
acc.withdraw(30)
print(acc.get_balance())  # Output: 120
# print(acc.__balance)  # Raises AttributeError: 'Account' object has no attribute '__balance'
```

**Summary**:
- **Encapsulation**: Bundles data and methods in a class and restricts direct access to some components.
- **Example**: Using private attributes and public methods to manage access and modifications.

# %%
#what is polymorphism ? explain it with an example
**Polymorphism** in Python refers to the ability of different objects to be treated as instances of the same class through a common interface, typically by overriding methods. It allows methods to have the same name but behave differently based on the object calling them.

### Key Points
- **Method Overriding**: Subclasses can provide specific implementations of methods defined in their superclasses.
- **Dynamic Behavior**: The method called is determined at runtime based on the object’s type.

### Example

```python
class Animal:
    def speak(self):
        return "Animal sound"

class Dog(Animal):
    def speak(self):
        return "Woof!"

class Cat(Animal):
    def speak(self):
        return "Meow!"

def make_animal_speak(animal):
    print(animal.speak())

# Usage
dog = Dog()
cat = Cat()

make_animal_speak(dog)  # Output: Woof!
make_animal_speak(cat)  # Output: Meow!
```

**Summary**:
- **Polymorphism**: Enables objects to be treated as instances of a common class with overridden method implementations.
- **Example**: Different animals (Dog and Cat) implementing the `speak` method differently, but used interchangeably.

# %% [markdown]
# # Question1.2.which of the folliwing identifier names are invalid and why ?

# %%
#a) serial_no.
The identifier name `serial_no` is **valid** in Python. Here’s why:

### Why `serial_no` is Valid
1. **Starts with a Letter or Underscore**: `serial_no` starts with the letter `s`, which is allowed.
2. **Contains Only Letters, Digits, and Underscores**: The identifier includes letters (`serial`), digits (`no`), and underscores (`_`). All these are permissible characters in Python identifiers.
3. **No Spaces or Special Characters**: There are no spaces or special characters like `@`, `#`, etc.
4. **Not a Reserved Keyword**: `serial_no` is not a Python reserved keyword.

### Summary
- **Valid Identifier**: `serial_no` adheres to Python’s identifier rules: it starts with a letter, uses only allowed characters, and is not a reserved keyword.

# %%
b)1st_Room.
The identifier name `1st_Room` is **invalid** in Python. Here's why:

### Reasons for Invalidity
1. **Starts with a Digit**: Identifiers in Python cannot start with a digit. They must start with a letter (a-z, A-Z) or an underscore (_).
2. **Contains Valid Characters**: While the rest of the characters (letters and the underscore) are valid, the initial digit disqualifies the entire identifier.

### Correct Form
To make `1st_Room` a valid identifier, it should start with a letter or an underscore:

```python
first_Room = "Valid"  # Corrected identifier
_room1 = "Also valid"
```

**Summary**:
- **Invalid**: `1st_Room` starts with a digit, which is not allowed for identifiers in Python.

# %%
#c)Hundred$
The identifier name `Hundred$` is **invalid** in Python. Here's why:

### Reason for Invalidity
- **Contains Special Characters**: Identifiers in Python cannot contain special characters such as `$`. They can only include letters (a-z, A-Z), digits (0-9), and underscores (_).

### Correct Form
To make `Hundred$` a valid identifier, replace the special character with an underscore or remove it:

```python
Hundred_dollars = "Valid"  # Corrected identifier with underscore
hundred = "Valid"  # Simplified valid identifier
```

**Summary**:
- **Invalid**: `Hundred$` includes a special character `$`, which is not allowed in Python identifiers.

# %%
#d)Total_Marks.
The identifier name `Total_Marks` is **valid** in Python. Here's why:

### Reasons for Validity
1. **Starts with a Letter**: `Total_Marks` starts with a letter (`T`), which is allowed.
2. **Contains Valid Characters**: The identifier uses only letters (`Total`, `Marks`) and an underscore (`_`), which are permissible characters in Python identifiers.
3. **No Spaces or Special Characters**: There are no spaces or special characters in the identifier.

### Summary
- **Valid**: `Total_Marks` adheres to Python’s identifier rules: it starts with a letter, contains only letters and underscores, and does not include invalid characters or spaces.

# %%
#e)toatl-marks
The identifier name `total-marks` is **invalid** in Python. Here's why:

### Reason for Invalidity
- **Contains a Hyphen**: Identifiers in Python cannot include hyphens (`-`). They can only consist of letters (a-z, A-Z), digits (0-9), and underscores (`_`).

### Correct Form
To correct this identifier, replace the hyphen with an underscore:

```python
total_marks = "Valid"  # Corrected identifier
```

**Summary**:
- **Invalid**: `total-marks` includes a hyphen (`-`), which is not allowed in Python identifiers. Use underscores (`_`) instead.

# %%
#f) Total Marks
The identifier name `Toatal Marks` is **invalid** in Python. Here's why:

### Reason for Invalidity
- **Contains a Space**: Identifiers in Python cannot contain spaces. They must be a single contiguous sequence of letters, digits, and underscores.

### Correct Form
To correct this identifier, replace the space with an underscore or remove it:

```python
Total_Marks = "Valid"  # Corrected identifier with an underscore
totalMarks = "Valid"   # Another valid option without spaces
```

**Summary**:
- **Invalid**: `Toatal Marks` contains a space, which is not allowed in Python identifiers. Use underscores or remove spaces for valid identifiers.

# %%
#g) True
The identifier name `True` is **invalid** in Python for the following reason:

### Reason for Invalidity
- **Reserved Keyword**: `True` is a reserved keyword in Python. It represents a Boolean value and cannot be used as an identifier name.

### Summary
- **Invalid**: `True` is a keyword in Python and cannot be used as a variable name or identifier. Choose a different name for your variables or identifiers.

# %%
#h)_Percentag
The identifier name `_Percentag` is **valid** in Python. Here's why:

### Reasons for Validity
1. **Starts with an Underscore**: Identifiers can start with an underscore (`_`), which is allowed.
2. **Contains Valid Characters**: The identifier contains only letters (`Percentag`) and an underscore, both of which are permissible characters in Python identifiers.
3. **No Spaces or Special Characters**: The identifier does not contain any spaces or special characters other than the underscore.

### Summary
- **Valid**: `_Percentag` adheres to Python’s identifier rules: it starts with an underscore and uses only allowed characters (letters and underscore).
